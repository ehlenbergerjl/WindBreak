# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # VISUALIZATIONS IN PYTHON

# %% [markdown]
# Top libraries in Python for visualization:
# 1. Matplotlib: It is the most popular package for visualization.
# 2. Plotly: It's more suitable for beginners.
# 3. Ggplot: This was initially developed in R. The functionality of the GGPLOT is that "it refers to the map of the data, with its aesthetic attributes including color, shape, and geometric objects like points and bars."
# 4. Seaborn: "It offers a variety of visualization patterns."
# 5. Leafly:
#
# ### GEOSPATIAL VISUALIZATION:
# 1. Plotly:
# 2. Geoplot :
#
# Less used libraries: cartopy, Cython, Shapely, GEOS, pyshp, Proj, Six
#
#
# References:
# https://knowledgehut.com/blog/business-intelligence-and-visualization/python-data-visualization-libraries

# %% [markdown]
# ## Geoplot
# https://residentmario.github.io/geoplot/index.html

# %% [markdown]
# ![image.png](attachment:43f8335c-8c4e-430f-a16c-131589916442.png)

# %% [markdown]
# ## PLOTLY
# https://plotly.com/python/

# %% [markdown]
# ![image.png](attachment:aa410b28-db42-4510-97a0-a56226e7b26f.png)

# %%
# import packages 
import os

# %%
# pip install geoplot

# %%
os.getcwd()
# Out:
# '/home/students/ehlenbergerjl/Module7_Visualization_PartI'

# %%
import os 
import geopandas as gpd 
import geoplot as gplt
import matplotlib.pyplot as plt

# %%
shp = gpd.read_file('NE_KS_county.shp')

# %%
shp.head(2)
# Out:
#   STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID       NAME LSAD  \
# 0      20      053  00484996  0500000US20053  20053  Ellsworth   06
# 1      20      095  00485012  0500000US20095  20095    Kingman   06
#
#         ALAND    AWATER                                           geometry
# 0  1853331063  19969761  POLYGON ((-98.48554 38.78395, -98.48561 38.794...
# 1  2236100137   8536908  POLYGON ((-98.46489 37.64530, -98.46481 37.703...

# %%
# from matplotlib package 
shp.plot()
# Out:
# <Axes: >

# %%
# set up the axis 
fig,ax = plt.subplots(figsize=(10,10))

# %%
# common cmap = magma, 

# set up the axis 
fig,ax = plt.subplots(figsize = (10,10))
shp.plot(ax = ax, column = 'AWATER', cmap = 'Reds', legend_kwds = {'shrink'})
ax.axis('off')
ax.set_title("Total water area (m2) in KE and KS")
#ax.set_title("Total water area (m2) in KE and KS", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Total water area (m2) in KE and KS')

# %%
# pip install plotly

# %%
# pip install cartopy
